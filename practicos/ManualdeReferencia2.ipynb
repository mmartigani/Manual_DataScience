# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("adult.data")
df
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0         Exec-managerial         Husband   White     Male      0   0   13
# 1       Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2       Handlers-cleaners         Husband   Black     Male      0   0   40
# 3          Prof-specialty            Wife   Black   Female      0   0   40
# 4         Exec-managerial            Wife   White   Female      0   0   40
# ...                   ...             ...     ...      ...    ...  ..  ...
# 32555        Tech-support            Wife   White   Female      0   0   38
# 32556   Machine-op-inspct         Husband   White     Male      0   0   40
# 32557        Adm-clerical       Unmarried   White   Female      0   0   40
# 32558        Adm-clerical       Own-child   White     Male      0   0   20
# 32559     Exec-managerial            Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3                Cuba   <=50K
# 4       United-States   <=50K
# ...               ...     ...
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K
#
# [32560 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
df.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
df.head(n=2)
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
#
#          Adm-clerical   Not-in-family   White   Male   2174   0   40  \
# 0     Exec-managerial         Husband   White   Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White   Male      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K

# %%
df.tail()
# Out:
#        39      State-gov   77516    Bachelors   13        Never-married  \
# 32555  27        Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40        Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58        Private  151910      HS-grad    9              Widowed
# 32558  22        Private  201490      HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
#              Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32555        Tech-support           Wife   White   Female      0   0   38
# 32556   Machine-op-inspct        Husband   White     Male      0   0   40
# 32557        Adm-clerical      Unmarried   White   Female      0   0   40
# 32558        Adm-clerical      Own-child   White     Male      0   0   20
# 32559     Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K

# %%
df.tail(n=2)
# Out:
#        39      State-gov   77516  Bachelors   13        Never-married  \
# 32558  22        Private  201490    HS-grad    9        Never-married
# 32559  52   Self-emp-inc  287927    HS-grad    9   Married-civ-spouse
#
#            Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 32558      Adm-clerical      Own-child   White     Male      0   0   20
# 32559   Exec-managerial           Wife   White   Female  15024   0   40
#
#         United-States   <=50K
# 32558   United-States   <=50K
# 32559   United-States    >50K

# %%
df.sample()
# Out:
#        39          State-gov   77516      Bachelors   13   Never-married  \
# 31781  38   Self-emp-not-inc  238980   Some-college   10   Never-married
#
#        Adm-clerical   Not-in-family   White   Male   2174   0   40  \
# 31781         Sales   Not-in-family   White   Male      0   0   60
#
#         United-States   <=50K
# 31781   United-States   <=50K

# %%
df.sample(n = 5)
# Out:
#        39  State-gov   77516      Bachelors   13        Never-married  \
# 26947  44    Private  317320   Some-college   10             Divorced
# 19616  59    Private  182460      Bachelors   13   Married-civ-spouse
# 13914  22    Private  446140        HS-grad    9        Never-married
# 12331  40    Private  558944        7th-8th    4        Never-married
# 31532  43    Private  226902        HS-grad    9   Married-civ-spouse
#
#            Adm-clerical  Not-in-family   White     Male   2174   0   40  \
# 26947     Other-service      Unmarried   White   Female      0   0   40
# 19616   Exec-managerial        Husband   White     Male      0   0   60
# 13914             Sales      Own-child   White     Male      0   0   55
# 12331   Farming-fishing      Own-child   White     Male      0   0   40
# 31532             Sales        Husband   White     Male      0   0   80
#
#         United-States   <=50K
# 26947   United-States   <=50K
# 19616   United-States    >50K
# 13914   United-States   <=50K
# 12331   United-States   <=50K
# 31532   United-States    >50K

# %%
df.sample(n = 5, random_state=10)
# Out:
#        39      State-gov   77516      Bachelors   13        Never-married  \
# 11358  41        Private  134130      Bachelors   13   Married-civ-spouse
# 10859  38        Private  107302   Some-college   10   Married-civ-spouse
# 30948  24        Private  136687        HS-grad    9            Separated
# 29811  35   Self-emp-inc  187053      Bachelors   13            Separated
# 18408  69              ?  254834      Bachelors   13   Married-civ-spouse
#
#              Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 11358               Sales         Husband   White     Male      0   0   50
# 10859               Sales         Husband   White     Male      0   0   60
# 30948   Machine-op-inspct       Unmarried   Other   Female      0   0   40
# 29811      Prof-specialty   Not-in-family   White   Female      0   0   50
# 18408                   ?         Husband   White     Male  10605   0   10
#
#         United-States   <=50K
# 11358   United-States    >50K
# 10859   United-States    >50K
# 30948   United-States   <=50K
# 29811   United-States   <=50K
# 18408   United-States    >50K

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32560, step=1)

# %%
df.index.values
# Out:
# array([    0,     1,     2, ..., 32557, 32558, 32559], dtype=int64)

# %%
df.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
df[0:4]
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K

# %%
df[0:-2]
# Out:
#        39          State-gov   77516      Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311      Bachelors   13   Married-civ-spouse
# 1      38            Private  215646        HS-grad    9             Divorced
# 2      53            Private  234721           11th    7   Married-civ-spouse
# 3      28            Private  338409      Bachelors   13   Married-civ-spouse
# 4      37            Private  284582        Masters   14   Married-civ-spouse
# ...    ..                ...     ...            ...  ...                  ...
# 32553  53            Private  321865        Masters   14   Married-civ-spouse
# 32554  22            Private  310152   Some-college   10        Never-married
# 32555  27            Private  257302     Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374        HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910        HS-grad    9              Widowed
#
#              Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0         Exec-managerial         Husband   White     Male      0   0   13
# 1       Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2       Handlers-cleaners         Husband   Black     Male      0   0   40
# 3          Prof-specialty            Wife   Black   Female      0   0   40
# 4         Exec-managerial            Wife   White   Female      0   0   40
# ...                   ...             ...     ...      ...    ...  ..  ...
# 32553     Exec-managerial         Husband   White     Male      0   0   40
# 32554     Protective-serv   Not-in-family   White     Male      0   0   40
# 32555        Tech-support            Wife   White   Female      0   0   38
# 32556   Machine-op-inspct         Husband   White     Male      0   0   40
# 32557        Adm-clerical       Unmarried   White   Female      0   0   40
#
#         United-States   <=50K
# 0       United-States   <=50K
# 1       United-States   <=50K
# 2       United-States   <=50K
# 3                Cuba   <=50K
# 4       United-States   <=50K
# ...               ...     ...
# 32553   United-States    >50K
# 32554   United-States   <=50K
# 32555   United-States   <=50K
# 32556   United-States    >50K
# 32557   United-States   <=50K
#
# [32558 rows x 15 columns]

# %%
df[:3]
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White   Male   2174   0   40  \
# 0     Exec-managerial         Husband   White   Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White   Male      0   0   40
# 2   Handlers-cleaners         Husband   Black   Male      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K

# %%
file_path = "adult.data"

col_names = ["age", 
            "workclass",
            "fnlwgt", 
            "education",
            "education-num",
            "marital-status",
            "occupation",
            "relationship",
            "race",
            "sex",
            "capital-gain",
            "capital-loss",
            "hours-per-week",
            "native-country",
            "income"]


adult_data = pd.read_csv(filepath_or_buffer = file_path,
           header = 0,
           names = col_names)
adult_data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
adult_data.occupation
# Out:
# 0           Exec-managerial
# 1         Handlers-cleaners
# 2         Handlers-cleaners
# 3            Prof-specialty
# 4           Exec-managerial
#                 ...
# 32555          Tech-support
# 32556     Machine-op-inspct
# 32557          Adm-clerical
# 32558          Adm-clerical
# 32559       Exec-managerial
# Name: occupation, Length: 32560, dtype: object

# %%
adult_data["occupation"]
# Out:
# 0           Exec-managerial
# 1         Handlers-cleaners
# 2         Handlers-cleaners
# 3            Prof-specialty
# 4           Exec-managerial
#                 ...
# 32555          Tech-support
# 32556     Machine-op-inspct
# 32557          Adm-clerical
# 32558          Adm-clerical
# 32559       Exec-managerial
# Name: occupation, Length: 32560, dtype: object

# %%
adult_data["hours-per-week"]
# Out:
# 0        13
# 1        40
# 2        40
# 3        40
# 4        40
#          ..
# 32555    38
# 32556    40
# 32557    40
# 32558    20
# 32559    40
# Name: hours-per-week, Length: 32560, dtype: int64

# %%
adult_data["hours-per-week"][32555]
# Out:
# 38

# %%
adult_data.iloc[0]
# Out:
# age                                50
# workclass            Self-emp-not-inc
# fnlwgt                          83311
# education                   Bachelors
# education-num                      13
# marital-status     Married-civ-spouse
# occupation            Exec-managerial
# relationship                  Husband
# race                            White
# sex                              Male
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     13
# native-country          United-States
# income                          <=50K
# Name: 0, dtype: object

# %%
adult_data.iloc[32555]
# Out:
# age                                27
# workclass                     Private
# fnlwgt                         257302
# education                  Assoc-acdm
# education-num                      12
# marital-status     Married-civ-spouse
# occupation               Tech-support
# relationship                     Wife
# race                            White
# sex                            Female
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     38
# native-country          United-States
# income                          <=50K
# Name: 32555, dtype: object

# %%
adult_data[0:3]
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
#
#         marital-status          occupation    relationship    race    sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K

# %%
adult_data.iloc[0:3]
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
#
#         marital-status          occupation    relationship    race    sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K

# %%
adult_data.iloc[-1]
# Out:
# age                                52
# workclass                Self-emp-inc
# fnlwgt                         287927
# education                     HS-grad
# education-num                       9
# marital-status     Married-civ-spouse
# occupation            Exec-managerial
# relationship                     Wife
# race                            White
# sex                            Female
# capital-gain                    15024
# capital-loss                        0
# hours-per-week                     40
# native-country          United-States
# income                           >50K
# Name: 32559, dtype: object

# %%
adult_data.iloc[-2]
# Out:
# age                           22
# workclass                Private
# fnlwgt                    201490
# education                HS-grad
# education-num                  9
# marital-status     Never-married
# occupation          Adm-clerical
# relationship           Own-child
# race                       White
# sex                         Male
# capital-gain                   0
# capital-loss                   0
# hours-per-week                20
# native-country     United-States
# income                     <=50K
# Name: 32558, dtype: object

# %%
adult_data.iloc[:, 0]
# Out:
# 0        50
# 1        38
# 2        53
# 3        28
# 4        37
#          ..
# 32555    27
# 32556    40
# 32557    58
# 32558    22
# 32559    52
# Name: age, Length: 32560, dtype: int64

# %%
adult_data.iloc[:, -1]
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32555     <=50K
# 32556      >50K
# 32557     <=50K
# 32558     <=50K
# 32559      >50K
# Name: income, Length: 32560, dtype: object

# %%
adult_data.iloc[0:3]
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
#
#         marital-status          occupation    relationship    race    sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K

# %%
adult_data.iloc[0:3, 0]
# Out:
# 0    50
# 1    38
# 2    53
# Name: age, dtype: int64

# %%
adult_data.iloc[:, 0:3]
# Out:
#        age          workclass  fnlwgt
# 0       50   Self-emp-not-inc   83311
# 1       38            Private  215646
# 2       53            Private  234721
# 3       28            Private  338409
# 4       37            Private  284582
# ...    ...                ...     ...
# 32555   27            Private  257302
# 32556   40            Private  154374
# 32557   58            Private  151910
# 32558   22            Private  201490
# 32559   52       Self-emp-inc  287927
#
# [32560 rows x 3 columns]

# %%
adult_data.iloc[1:3, 0]
# Out:
# 1    38
# 2    53
# Name: age, dtype: int64

# %%
adult_data.iloc[[0, 1, 2]]
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
#
#         marital-status          occupation    relationship    race    sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K

# %%
adult_data.iloc[[0, 1, 2], :]
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
#
#         marital-status          occupation    relationship    race    sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K

# %%
adult_data.iloc[[0,1,2], 0]
# Out:
# 0    50
# 1    38
# 2    53
# Name: age, dtype: int64

# %%
adult_data.iloc[:, [0, 2, 4]]
# Out:
#        age  fnlwgt  education-num
# 0       50   83311             13
# 1       38  215646              9
# 2       53  234721              7
# 3       28  338409             13
# 4       37  284582             14
# ...    ...     ...            ...
# 32555   27  257302             12
# 32556   40  154374              9
# 32557   58  151910              9
# 32558   22  201490              9
# 32559   52  287927              9
#
# [32560 rows x 3 columns]

# %%
adult_data.iloc[-5]
# Out:
# age                                27
# workclass                     Private
# fnlwgt                         257302
# education                  Assoc-acdm
# education-num                      12
# marital-status     Married-civ-spouse
# occupation               Tech-support
# relationship                     Wife
# race                            White
# sex                            Female
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     38
# native-country          United-States
# income                          <=50K
# Name: 32555, dtype: object

# %%
adult_data.iloc[-5, :]
# Out:
# age                                27
# workclass                     Private
# fnlwgt                         257302
# education                  Assoc-acdm
# education-num                      12
# marital-status     Married-civ-spouse
# occupation               Tech-support
# relationship                     Wife
# race                            White
# sex                            Female
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     38
# native-country          United-States
# income                          <=50K
# Name: 32555, dtype: object

# %%
df = pd.DataFrame({"Columna1": 10,
                  "Columna2": 20,
                  "Columna3": 30},
                 index = ["Fila1", "Fila2", "Fila3"])
df
# Out:
#        Columna1  Columna2  Columna3
# Fila1        10        20        30
# Fila2        10        20        30
# Fila3        10        20        30

# %%
df.loc["Fila1", "Columna1"]
# Out:
# 10

# %%
adult_data.loc[:, ["education", "marital-status", "relationship"]]
# Out:
#          education       marital-status    relationship
# 0        Bachelors   Married-civ-spouse         Husband
# 1          HS-grad             Divorced   Not-in-family
# 2             11th   Married-civ-spouse         Husband
# 3        Bachelors   Married-civ-spouse            Wife
# 4          Masters   Married-civ-spouse            Wife
# ...            ...                  ...             ...
# 32555   Assoc-acdm   Married-civ-spouse            Wife
# 32556      HS-grad   Married-civ-spouse         Husband
# 32557      HS-grad              Widowed       Unmarried
# 32558      HS-grad        Never-married       Own-child
# 32559      HS-grad   Married-civ-spouse            Wife
#
# [32560 rows x 3 columns]

# %%
adult_data.loc[0, "education"]
# Out:
# ' Bachelors'

# %%
adult_data.loc[0:10, ["education", "marital-status", "relationship"]]
# Out:
#         education          marital-status    relationship
# 0       Bachelors      Married-civ-spouse         Husband
# 1         HS-grad                Divorced   Not-in-family
# 2            11th      Married-civ-spouse         Husband
# 3       Bachelors      Married-civ-spouse            Wife
# 4         Masters      Married-civ-spouse            Wife
# 5             9th   Married-spouse-absent   Not-in-family
# 6         HS-grad      Married-civ-spouse         Husband
# 7         Masters           Never-married   Not-in-family
# 8       Bachelors      Married-civ-spouse         Husband
# 9    Some-college      Married-civ-spouse         Husband
# 10      Bachelors      Married-civ-spouse         Husband

# %%
adult_data.iloc[0:10, :]
# Out:
#    age          workclass  fnlwgt      education  education-num  \
# 0   50   Self-emp-not-inc   83311      Bachelors             13
# 1   38            Private  215646        HS-grad              9
# 2   53            Private  234721           11th              7
# 3   28            Private  338409      Bachelors             13
# 4   37            Private  284582        Masters             14
# 5   49            Private  160187            9th              5
# 6   52   Self-emp-not-inc  209642        HS-grad              9
# 7   31            Private   45781        Masters             14
# 8   42            Private  159449      Bachelors             13
# 9   37            Private  280464   Some-college             10
#
#            marital-status          occupation    relationship    race  \
# 0      Married-civ-spouse     Exec-managerial         Husband   White
# 1                Divorced   Handlers-cleaners   Not-in-family   White
# 2      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3      Married-civ-spouse      Prof-specialty            Wife   Black
# 4      Married-civ-spouse     Exec-managerial            Wife   White
# 5   Married-spouse-absent       Other-service   Not-in-family   Black
# 6      Married-civ-spouse     Exec-managerial         Husband   White
# 7           Never-married      Prof-specialty   Not-in-family   White
# 8      Married-civ-spouse     Exec-managerial         Husband   White
# 9      Married-civ-spouse     Exec-managerial         Husband   Black
#
#        sex  capital-gain  capital-loss  hours-per-week  native-country  income
# 0     Male             0             0              13   United-States   <=50K
# 1     Male             0             0              40   United-States   <=50K
# 2     Male             0             0              40   United-States   <=50K
# 3   Female             0             0              40            Cuba   <=50K
# 4   Female             0             0              40   United-States   <=50K
# 5   Female             0             0              16         Jamaica   <=50K
# 6     Male             0             0              45   United-States    >50K
# 7   Female         14084             0              50   United-States    >50K
# 8     Male          5178             0              40   United-States    >50K
# 9     Male             0             0              80   United-States    >50K

# %%
adult_data.loc[:, "marital-status"] == "Never-married"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32555    False
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# Name: marital-status, Length: 32560, dtype: bool

# %%
adult_data.loc[adult_data.loc[:, "marital-status"] == " Never-married"]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 7       31            Private   45781        Masters             14
# 11      23            Private  122272      Bachelors             13
# 12      32            Private  205019     Assoc-acdm             12
# 15      25   Self-emp-not-inc  176756        HS-grad              9
# 16      32            Private  186824        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32536   30            Private  345898        HS-grad              9
# 32547   65   Self-emp-not-inc   99359    Prof-school             15
# 32552   32            Private  116138        Masters             14
# 32554   22            Private  310152   Some-college             10
# 32558   22            Private  201490        HS-grad              9
#
#        marital-status          occupation    relationship  \
# 7       Never-married      Prof-specialty   Not-in-family
# 11      Never-married        Adm-clerical       Own-child
# 12      Never-married               Sales   Not-in-family
# 15      Never-married     Farming-fishing       Own-child
# 16      Never-married   Machine-op-inspct       Unmarried
# ...               ...                 ...             ...
# 32536   Never-married        Craft-repair   Not-in-family
# 32547   Never-married      Prof-specialty   Not-in-family
# 32552   Never-married        Tech-support   Not-in-family
# 32554   Never-married     Protective-serv   Not-in-family
# 32558   Never-married        Adm-clerical       Own-child
#
#                       race      sex  capital-gain  capital-loss  \
# 7                    White   Female         14084             0
# 11                   White   Female             0             0
# 12                   Black     Male             0             0
# 15                   White     Male             0             0
# 16                   White     Male             0             0
# ...                    ...      ...           ...           ...
# 32536                Black     Male             0             0
# 32547                White     Male          1086             0
# 32552   Asian-Pac-Islander     Male             0             0
# 32554                White     Male             0             0
# 32558                White     Male             0             0
#
#        hours-per-week  native-country  income
# 7                  50   United-States    >50K
# 11                 30   United-States   <=50K
# 12                 50   United-States   <=50K
# 15                 35   United-States   <=50K
# 16                 40   United-States   <=50K
# ...               ...             ...     ...
# 32536              46   United-States   <=50K
# 32547              60   United-States   <=50K
# 32552              11          Taiwan   <=50K
# 32554              40   United-States   <=50K
# 32558              20   United-States   <=50K
#
# [10682 rows x 15 columns]

# %%
adult_data.loc[:, "marital-status"].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Married-spouse-absent',
#        ' Never-married', ' Separated', ' Married-AF-spouse', ' Widowed'],
#       dtype=object)

# %%
adult_data.loc[(adult_data.loc[:, "marital-status"] == " Never-married") &
              (adult_data.loc[:, "hours-per-week"] >= 40)]
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 7       31            Private   45781        Masters             14
# 12      32            Private  205019     Assoc-acdm             12
# 16      32            Private  186824        HS-grad              9
# 25      19            Private  168294        HS-grad              9
# 29      23          Local-gov  190709     Assoc-acdm             12
# ...    ...                ...     ...            ...            ...
# 32530   30                  ?   33811      Bachelors             13
# 32535   34            Private  160216      Bachelors             13
# 32536   30            Private  345898        HS-grad              9
# 32547   65   Self-emp-not-inc   99359    Prof-school             15
# 32554   22            Private  310152   Some-college             10
#
#        marital-status          occupation    relationship  \
# 7       Never-married      Prof-specialty   Not-in-family
# 12      Never-married               Sales   Not-in-family
# 16      Never-married   Machine-op-inspct       Unmarried
# 25      Never-married        Craft-repair       Own-child
# 29      Never-married     Protective-serv   Not-in-family
# ...               ...                 ...             ...
# 32530   Never-married                   ?   Not-in-family
# 32535   Never-married     Exec-managerial   Not-in-family
# 32536   Never-married        Craft-repair   Not-in-family
# 32547   Never-married      Prof-specialty   Not-in-family
# 32554   Never-married     Protective-serv   Not-in-family
#
#                       race      sex  capital-gain  capital-loss  \
# 7                    White   Female         14084             0
# 12                   Black     Male             0             0
# 16                   White     Male             0             0
# 25                   White     Male             0             0
# 29                   White     Male             0             0
# ...                    ...      ...           ...           ...
# 32530   Asian-Pac-Islander   Female             0             0
# 32535                White   Female             0             0
# 32536                Black     Male             0             0
# 32547                White     Male          1086             0
# 32554                White     Male             0             0
#
#        hours-per-week  native-country  income
# 7                  50   United-States    >50K
# 12                 50   United-States   <=50K
# 16                 40   United-States   <=50K
# 25                 40   United-States   <=50K
# 29                 52   United-States   <=50K
# ...               ...             ...     ...
# 32530              99   United-States   <=50K
# 32535              55   United-States    >50K
# 32536              46   United-States   <=50K
# 32547              60   United-States   <=50K
# 32554              40   United-States   <=50K
#
# [6872 rows x 15 columns]

# %%
adult_data.loc[:, "marital-status"]
# Out:
# 0         Married-civ-spouse
# 1                   Divorced
# 2         Married-civ-spouse
# 3         Married-civ-spouse
# 4         Married-civ-spouse
#                 ...
# 32555     Married-civ-spouse
# 32556     Married-civ-spouse
# 32557                Widowed
# 32558          Never-married
# 32559     Married-civ-spouse
# Name: marital-status, Length: 32560, dtype: object

# %%
adult_data["marital-status"]
# Out:
# 0         Married-civ-spouse
# 1                   Divorced
# 2         Married-civ-spouse
# 3         Married-civ-spouse
# 4         Married-civ-spouse
#                 ...
# 32555     Married-civ-spouse
# 32556     Married-civ-spouse
# 32557                Widowed
# 32558          Never-married
# 32559     Married-civ-spouse
# Name: marital-status, Length: 32560, dtype: object

# %%
value_list = [" Bachelors", " Masters"]
value_list
# Out:
# [' Bachelors', ' Masters']

# %%
adult_data.loc[:, "education"].isin(value_list)
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4         True
#          ...
# 32555    False
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# Name: education, Length: 32560, dtype: bool

# %%
adult_data.loc[adult_data.loc[:, "education"].isin(value_list)]
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       50   Self-emp-not-inc   83311   Bachelors             13
# 3       28            Private  338409   Bachelors             13
# 4       37            Private  284582     Masters             14
# 7       31            Private   45781     Masters             14
# 8       42            Private  159449   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32535   34            Private  160216   Bachelors             13
# 32537   38            Private  139180   Bachelors             13
# 32543   31            Private  199655     Masters             14
# 32552   32            Private  116138     Masters             14
# 32553   53            Private  321865     Masters             14
#
#             marital-status        occupation    relationship  \
# 0       Married-civ-spouse   Exec-managerial         Husband
# 3       Married-civ-spouse    Prof-specialty            Wife
# 4       Married-civ-spouse   Exec-managerial            Wife
# 7            Never-married    Prof-specialty   Not-in-family
# 8       Married-civ-spouse   Exec-managerial         Husband
# ...                    ...               ...             ...
# 32535        Never-married   Exec-managerial   Not-in-family
# 32537             Divorced    Prof-specialty       Unmarried
# 32543             Divorced     Other-service   Not-in-family
# 32552        Never-married      Tech-support   Not-in-family
# 32553   Married-civ-spouse   Exec-managerial         Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male             0             0
# 3                    Black   Female             0             0
# 4                    White   Female             0             0
# 7                    White   Female         14084             0
# 8                    White     Male          5178             0
# ...                    ...      ...           ...           ...
# 32535                White   Female             0             0
# 32537                Black   Female         15020             0
# 32543                Other   Female             0             0
# 32552   Asian-Pac-Islander     Male             0             0
# 32553                White     Male             0             0
#
#        hours-per-week  native-country  income
# 0                  13   United-States   <=50K
# 3                  40            Cuba   <=50K
# 4                  40   United-States   <=50K
# 7                  50   United-States    >50K
# 8                  40   United-States    >50K
# ...               ...             ...     ...
# 32535              55   United-States    >50K
# 32537              45   United-States    >50K
# 32543              30   United-States   <=50K
# 32552              11          Taiwan   <=50K
# 32553              40   United-States    >50K
#
# [7077 rows x 15 columns]

# %%
adult_data.loc[:, "education"].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %%
adult_data.loc[:, "education-num"] = "valor_constante"

# %%
adult_data.occupation = "occupation"

# %%
adult_data["marital-status"] = "estado"

# %%
adult_data["relationship"] = range(len(adult_data))

# %%
adult_data["marital-status"] = adult_data["occupation"]

# %%
adult_data.loc[adult_data["education"] == " Bachelors", "marital-status"] = "X"

# %%
adult_data.loc[adult_data["education"] == " HS-grad", ["marital-status", "race"]] = "Y", "Z"

# %%
adult_data
# Out:
#        age          workclass  fnlwgt    education    education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors  valor_constante
# 1       38            Private  215646      HS-grad  valor_constante
# 2       53            Private  234721         11th  valor_constante
# 3       28            Private  338409    Bachelors  valor_constante
# 4       37            Private  284582      Masters  valor_constante
# ...    ...                ...     ...          ...              ...
# 32555   27            Private  257302   Assoc-acdm  valor_constante
# 32556   40            Private  154374      HS-grad  valor_constante
# 32557   58            Private  151910      HS-grad  valor_constante
# 32558   22            Private  201490      HS-grad  valor_constante
# 32559   52       Self-emp-inc  287927      HS-grad  valor_constante
#
#       marital-status  occupation  relationship    race      sex  capital-gain  \
# 0                  X  occupation             0   White     Male             0
# 1                  Y  occupation             1       Z     Male             0
# 2         occupation  occupation             2   Black     Male             0
# 3                  X  occupation             3   Black   Female             0
# 4         occupation  occupation             4   White   Female             0
# ...              ...         ...           ...     ...      ...           ...
# 32555     occupation  occupation         32555   White   Female             0
# 32556              Y  occupation         32556       Z     Male             0
# 32557              Y  occupation         32557       Z   Female             0
# 32558              Y  occupation         32558       Z     Male             0
# 32559              Y  occupation         32559       Z   Female         15024
#
#        capital-loss  hours-per-week  native-country  income
# 0                 0              13   United-States   <=50K
# 1                 0              40   United-States   <=50K
# 2                 0              40   United-States   <=50K
# 3                 0              40            Cuba   <=50K
# 4                 0              40   United-States   <=50K
# ...             ...             ...             ...     ...
# 32555             0              38   United-States   <=50K
# 32556             0              40   United-States    >50K
# 32557             0              40   United-States   <=50K
# 32558             0              20   United-States   <=50K
# 32559             0              40   United-States    >50K
#
# [32560 rows x 15 columns]

# %%
adult_data["new_column"] = "New"

# %%
adult_data.loc[adult_data["sex"] == " Male", "nueva_columna"] = "M"

# %%
adult_data.loc[adult_data["sex"] != " Male", "nueva_columna2"] = "F"

# %%
adult_data["sex"].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
adult_data
# Out:
#        age          workclass  fnlwgt    education    education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors  valor_constante
# 1       38            Private  215646      HS-grad  valor_constante
# 2       53            Private  234721         11th  valor_constante
# 3       28            Private  338409    Bachelors  valor_constante
# 4       37            Private  284582      Masters  valor_constante
# ...    ...                ...     ...          ...              ...
# 32555   27            Private  257302   Assoc-acdm  valor_constante
# 32556   40            Private  154374      HS-grad  valor_constante
# 32557   58            Private  151910      HS-grad  valor_constante
# 32558   22            Private  201490      HS-grad  valor_constante
# 32559   52       Self-emp-inc  287927      HS-grad  valor_constante
#
#       marital-status  occupation  relationship    race      sex  capital-gain  \
# 0                  X  occupation             0   White     Male             0
# 1                  Y  occupation             1       Z     Male             0
# 2         occupation  occupation             2   Black     Male             0
# 3                  X  occupation             3   Black   Female             0
# 4         occupation  occupation             4   White   Female             0
# ...              ...         ...           ...     ...      ...           ...
# 32555     occupation  occupation         32555   White   Female             0
# 32556              Y  occupation         32556       Z     Male             0
# 32557              Y  occupation         32557       Z   Female             0
# 32558              Y  occupation         32558       Z     Male             0
# 32559              Y  occupation         32559       Z   Female         15024
#
#        capital-loss  hours-per-week  native-country  income new_column  \
# 0                 0              13   United-States   <=50K        New
# 1                 0              40   United-States   <=50K        New
# 2                 0              40   United-States   <=50K        New
# 3                 0              40            Cuba   <=50K        New
# 4                 0              40   United-States   <=50K        New
# ...             ...             ...             ...     ...        ...
# 32555             0              38   United-States   <=50K        New
# 32556             0              40   United-States    >50K        New
# 32557             0              40   United-States   <=50K        New
# 32558             0              20   United-States   <=50K        New
# 32559             0              40   United-States    >50K        New
#
#       nueva_columna nueva_columna2
# 0                 M            NaN
# 1                 M            NaN
# 2                 M            NaN
# 3               NaN              F
# 4               NaN              F
# ...             ...            ...
# 32555           NaN              F
# 32556             M            NaN
# 32557           NaN              F
# 32558             M            NaN
# 32559           NaN              F
#
# [32560 rows x 18 columns]

# %%
df = pd.DataFrame({"Columna1": [10, 20, 30],
                  "Columna2": [40, 50, 60],
                  "Columna3": 30},
                 index = ["Fila1", "Fila2", "Fila3"])
df
# Out:
#        Columna1  Columna2  Columna3
# Fila1        10        40        30
# Fila2        20        50        30
# Fila3        30        60        30

# %%
nuevo_indice = ["Id1", "Id2", "Id3"]
nuevo_indice
# Out:
# ['Id1', 'Id2', 'Id3']

# %%
nuevo_indice_arr = np.array(["Id1", "Id2", "Id3"])
nuevo_indice_arr
# Out:
# array(['Id1', 'Id2', 'Id3'], dtype='<U3')

# %%
df.set_index(nuevo_indice_arr)
# Out:
#      Columna1  Columna2  Columna3
# Id1        10        40        30
# Id2        20        50        30
# Id3        30        60        30

# %%
df
# Out:
#        Columna1  Columna2  Columna3
# Fila1        10        40        30
# Fila2        20        50        30
# Fila3        30        60        30

# %%
df.set_index(nuevo_indice_arr, inplace=True)

# %%
df
# Out:
#      Columna1  Columna2  Columna3
# Id1        10        40        30
# Id2        20        50        30
# Id3        30        60        30

# %%
df = df.set_index(np.array(["i1", "i2", "i3"]), inplace=False)

# %%
df
# Out:
#     Columna1  Columna2  Columna3
# i1        10        40        30
# i2        20        50        30
# i3        30        60        30

# %%
df.set_index("Columna3", inplace=True)

# %%
df
# Out:
#           Columna1  Columna2
# Columna3
# 30              10        40
# 30              20        50
# 30              30        60

# %%
df["Columna4"] = [40, 40, 40]
df
# Out:
#           Columna1  Columna2  Columna4
# Columna3
# 30              10        40        40
# 30              20        50        40
# 30              30        60        40

# %%
df
# Out:
#           Columna1  Columna2  Columna4
# Columna3
# 30              10        40        40
# 30              20        50        40
# 30              30        60        40

# %%
df.index
# Out:
# Int64Index([30, 30, 30], dtype='int64', name='Columna3')

# %%
df.index.values
# Out:
# array([30, 30, 30], dtype=int64)

# %%
df.index.to_list()
# Out:
# [30, 30, 30]

# %%
file_path = "adult.data"

col_names = ["age", 
            "workclass",
            "fnlwgt", 
            "education",
            "education-num",
            "marital-status",
            "occupation",
            "relationship",
            "race",
            "sex",
            "capital-gain",
            "capital-loss",
            "hours-per-week",
            "native-country",
            "income"]


df = pd.read_csv(filepath_or_buffer = file_path,
           header = 0,
           names = col_names)
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# income            object
# dtype: object

# %%
df.values
# Out:
# array([[50, ' Self-emp-not-inc', 83311, ..., 13, ' United-States',
#         ' <=50K'],
#        [38, ' Private', 215646, ..., 40, ' United-States', ' <=50K'],
#        [53, ' Private', 234721, ..., 40, ' United-States', ' <=50K'],
#        ...,
#        [58, ' Private', 151910, ..., 40, ' United-States', ' <=50K'],
#        [22, ' Private', 201490, ..., 20, ' United-States', ' <=50K'],
#        [52, ' Self-emp-inc', 287927, ..., 40, ' United-States', ' >50K']],
#       dtype=object)

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (32560, 15)

# %%
df.size
# Out:
# 488400

# %%
df.apply(lambda x: x.unique())
# Out:
# age               [50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 3...
# workclass         [ Self-emp-not-inc,  Private,  State-gov,  Fed...
# fnlwgt            [83311, 215646, 234721, 338409, 284582, 160187...
# education         [ Bachelors,  HS-grad,  11th,  Masters,  9th, ...
# education-num     [13, 9, 7, 14, 5, 10, 12, 11, 4, 16, 15, 3, 6,...
# marital-status    [ Married-civ-spouse,  Divorced,  Married-spou...
# occupation        [ Exec-managerial,  Handlers-cleaners,  Prof-s...
# relationship      [ Husband,  Not-in-family,  Wife,  Own-child, ...
# race              [ White,  Black,  Asian-Pac-Islander,  Amer-In...
# sex                                                [ Male,  Female]
# capital-gain      [0, 14084, 5178, 5013, 2407, 14344, 15024, 768...
# capital-loss      [0, 2042, 1408, 1902, 1573, 1887, 1719, 1762, ...
# hours-per-week    [13, 40, 16, 45, 50, 80, 30, 35, 60, 20, 52, 4...
# native-country    [ United-States,  Cuba,  Jamaica,  India,  ?, ...
# income                                              [ <=50K,  >50K]
# dtype: object

# %%
df.workclass.unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df.nunique(axis=0, dropna=True)
# Out:
# age                  73
# workclass             9
# fnlwgt            21647
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        119
# capital-loss         92
# hours-per-week       94
# native-country       42
# income                2
# dtype: int64

# %%
df.max(axis = 0)
# Out:
# age                              90
# workclass               Without-pay
# fnlwgt                      1484705
# education              Some-college
# education-num                    16
# marital-status              Widowed
# occupation         Transport-moving
# relationship                   Wife
# race                          White
# sex                            Male
# capital-gain                  99999
# capital-loss                   4356
# hours-per-week                   99
# native-country           Yugoslavia
# income                         >50K
# dtype: object

# %%
df.min(axis=0)
# Out:
# age                                17
# workclass                           ?
# fnlwgt                          12285
# education                        10th
# education-num                       1
# marital-status               Divorced
# occupation                          ?
# relationship                  Husband
# race               Amer-Indian-Eskimo
# sex                            Female
# capital-gain                        0
# capital-loss                        0
# hours-per-week                      1
# native-country                      ?
# income                          <=50K
# dtype: object

# %%
df.duplicated(subset = ["marital-status"])
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 32555     True
# 32556     True
# 32557     True
# 32558     True
# 32559     True
# Length: 32560, dtype: bool

# %%
df[df.duplicated(subset = ["age", "marital-status"])]
# Out:
#        age      workclass  fnlwgt      education  education-num  \
# 9       37        Private  280464   Some-college             10
# 16      32        Private  186824        HS-grad              9
# 19      40        Private  193524      Doctorate             16
# 29      23      Local-gov  190709     Assoc-acdm             12
# 32      30    Federal-gov   59951   Some-college             10
# ...    ...            ...     ...            ...            ...
# 32555   27        Private  257302     Assoc-acdm             12
# 32556   40        Private  154374        HS-grad              9
# 32557   58        Private  151910        HS-grad              9
# 32558   22        Private  201490        HS-grad              9
# 32559   52   Self-emp-inc  287927        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 9       Married-civ-spouse     Exec-managerial         Husband   Black
# 16           Never-married   Machine-op-inspct       Unmarried   White
# 19      Married-civ-spouse      Prof-specialty         Husband   White
# 29           Never-married     Protective-serv   Not-in-family   White
# 32      Married-civ-spouse        Adm-clerical       Own-child   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 9         Male             0             0              80   United-States
# 16        Male             0             0              40   United-States
# 19        Male             0             0              60   United-States
# 29        Male             0             0              52   United-States
# 32        Male             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        income
# 9        >50K
# 16      <=50K
# 19       >50K
# 29      <=50K
# 32      <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32164 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32560 non-null  int64
#  1   workclass       32560 non-null  object
#  2   fnlwgt          32560 non-null  int64
#  3   education       32560 non-null  object
#  4   education-num   32560 non-null  int64
#  5   marital-status  32560 non-null  object
#  6   occupation      32560 non-null  object
#  7   relationship    32560 non-null  object
#  8   race            32560 non-null  object
#  9   sex             32560 non-null  object
#  10  capital-gain    32560 non-null  int64
#  11  capital-loss    32560 non-null  int64
#  12  hours-per-week  32560 non-null  int64
#  13  native-country  32560 non-null  object
#  14  income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe(include = "all")
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   32560.000000     32560  3.256000e+04     32560   32560.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581634       NaN  1.897818e+05       NaN      10.080590
# std        13.640642       NaN  1.055498e+05       NaN       2.572709
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178315e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783630e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370545e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              marital-status       occupation relationship    race    sex  \
# count                 32560            32560        32560   32560  32560
# unique                    7               15            6       5      2
# top      Married-civ-spouse   Prof-specialty      Husband   White   Male
# freq                  14976             4140        13193   27815  21789
# mean                    NaN              NaN          NaN     NaN    NaN
# std                     NaN              NaN          NaN     NaN    NaN
# min                     NaN              NaN          NaN     NaN    NaN
# 25%                     NaN              NaN          NaN     NaN    NaN
# 50%                     NaN              NaN          NaN     NaN    NaN
# 75%                     NaN              NaN          NaN     NaN    NaN
# max                     NaN              NaN          NaN     NaN    NaN
#
#         capital-gain  capital-loss  hours-per-week  native-country  income
# count   32560.000000  32560.000000    32560.000000           32560   32560
# unique           NaN           NaN             NaN              42       2
# top              NaN           NaN             NaN   United-States   <=50K
# freq             NaN           NaN             NaN           29169   24719
# mean     1077.615172     87.306511       40.437469             NaN     NaN
# std      7385.402999    402.966116       12.347618             NaN     NaN
# min         0.000000      0.000000        1.000000             NaN     NaN
# 25%         0.000000      0.000000       40.000000             NaN     NaN
# 50%         0.000000      0.000000       40.000000             NaN     NaN
# 75%         0.000000      0.000000       45.000000             NaN     NaN
# max     99999.000000   4356.000000       99.000000             NaN     NaN

# %%
uno = pd.DataFrame({"col1": [1, 2, 3],
                   "col2": [4, 5, 6],
                   "col3": [7, 8, 9]},
                  index = ["id1", "id2", "id3"])
uno
# Out:
#      col1  col2  col3
# id1     1     4     7
# id2     2     5     8
# id3     3     6     9

# %%
dos = pd.DataFrame({"col1": [10, 11, 12, 13],
                   "col2": [14, 15, 16, 17],
                   "col3": [18, 19, 20, 21]})
dos
# Out:
#    col1  col2  col3
# 0    10    14    18
# 1    11    15    19
# 2    12    16    20
# 3    13    17    21

# %%
tres = pd.DataFrame({"col1": ["a", "b", "c"],
                   "col2": ["d", "e", "f"],
                   "col3": ["g", "h", "i"],
                   "col4": ["j", "k", "l"]},
                  index = ["n1", "n2", "n3"])
tres
# Out:
#    col1 col2 col3 col4
# n1    a    d    g    j
# n2    b    e    h    k
# n3    c    f    i    l

# %%
cuatro = pd.DataFrame({"col1": ["a", "b", "c"],
                   "col2": ["d", "e", "f"],
                   "col3": ["g", "h", "i"],
                   "col4": ["j", "k", "l"]},
                  index = ["id1", "id2", "id3"])
cuatro
# Out:
#     col1 col2 col3 col4
# id1    a    d    g    j
# id2    b    e    h    k
# id3    c    f    i    l

# %%
uno
# Out:
#      col1  col2  col3
# id1     1     4     7
# id2     2     5     8
# id3     3     6     9

# %%
dos
# Out:
#    col1  col2  col3
# 0    10    14    18
# 1    11    15    19
# 2    12    16    20
# 3    13    17    21

# %%
tres
# Out:
#    col1 col2 col3 col4
# n1    a    d    g    j
# n2    b    e    h    k
# n3    c    f    i    l

# %%
cuatro
# Out:
#     col1 col2 col3 col4
# id1    a    d    g    j
# id2    b    e    h    k
# id3    c    f    i    l

# %%
pd.concat([uno, dos],
         axis = 0,
         join = "outer",
         ignore_index = False)
# Out:
#      col1  col2  col3
# id1     1     4     7
# id2     2     5     8
# id3     3     6     9
# 0      10    14    18
# 1      11    15    19
# 2      12    16    20
# 3      13    17    21

# %%
pd.concat([uno, dos],
         axis = 0,
         join = "inner",
         ignore_index = True)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
# 3    10    14    18
# 4    11    15    19
# 5    12    16    20
# 6    13    17    21

# %%
pd.concat([uno, dos],
         axis = 1,
         join = "outer",
         ignore_index = False)
# Out:
#      col1  col2  col3  col1  col2  col3
# id1   1.0   4.0   7.0   NaN   NaN   NaN
# id2   2.0   5.0   8.0   NaN   NaN   NaN
# id3   3.0   6.0   9.0   NaN   NaN   NaN
# 0     NaN   NaN   NaN  10.0  14.0  18.0
# 1     NaN   NaN   NaN  11.0  15.0  19.0
# 2     NaN   NaN   NaN  12.0  16.0  20.0
# 3     NaN   NaN   NaN  13.0  17.0  21.0

# %%
pd.concat([uno, dos],
         axis = 1,
         join = "inner",
         ignore_index = False)
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col1, col2, col3]
# Index: []

# %%
pd.concat([uno, dos],
         axis = 1,
         join = "inner",
         ignore_index = True)
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4, 5]
# Index: []

# %%
pd.concat([uno, cuatro],
         axis = 0,
         join = "outer",
         ignore_index = False)
# Out:
#     col1 col2 col3 col4
# id1    1    4    7  NaN
# id2    2    5    8  NaN
# id3    3    6    9  NaN
# id1    a    d    g    j
# id2    b    e    h    k
# id3    c    f    i    l

# %%
pd.concat([uno, cuatro],
         axis = 0,
         join = "inner",
         ignore_index = False)
# Out:
#     col1 col2 col3
# id1    1    4    7
# id2    2    5    8
# id3    3    6    9
# id1    a    d    g
# id2    b    e    h
# id3    c    f    i

# %%
serie1 = pd.Series(["s1", "s2", "s3"],
                  name = "col5",
                  index = ["n1", "n2", "n3"])
serie1
# Out:
# n1    s1
# n2    s2
# n3    s3
# Name: col5, dtype: object

# %%
serie2 = pd.Series(["s1", "s2", "s3"],
                  name = "col5",
                  index = ["id1", "id2", "id3"])
serie2
# Out:
# id1    s1
# id2    s2
# id3    s3
# Name: col5, dtype: object

# %%
pd.concat([uno, serie1],
         axis = 1,
         join = "outer",
         ignore_index = False)
# Out:
#      col1  col2  col3 col5
# id1   1.0   4.0   7.0  NaN
# id2   2.0   5.0   8.0  NaN
# id3   3.0   6.0   9.0  NaN
# n1    NaN   NaN   NaN   s1
# n2    NaN   NaN   NaN   s2
# n3    NaN   NaN   NaN   s3

# %%
pd.concat([uno, serie2],
         axis = 1,
         join = "outer",
         ignore_index = False)
# Out:
#      col1  col2  col3 col5
# id1     1     4     7   s1
# id2     2     5     8   s2
# id3     3     6     9   s3

# %%
uno.append(dos, ignore_index=False)
# Out:
#      col1  col2  col3
# id1     1     4     7
# id2     2     5     8
# id3     3     6     9
# 0      10    14    18
# 1      11    15    19
# 2      12    16    20
# 3      13    17    21

# %%
uno.append(dos, ignore_index=True)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9
# 3    10    14    18
# 4    11    15    19
# 5    12    16    20
# 6    13    17    21

# %%
uno.append(tres, ignore_index=False)
# Out:
#     col1 col2 col3 col4
# id1    1    4    7  NaN
# id2    2    5    8  NaN
# id3    3    6    9  NaN
# n1     a    d    g    j
# n2     b    e    h    k
# n3     c    f    i    l

# %%
uno.merge(dos, 
         how='inner',
         on = "col1")
# Out:
# Empty DataFrame
# Columns: [col1, col2_x, col3_x, col2_y, col3_y]
# Index: []

# %%
cinco = pd.DataFrame({"col1": ["b", "c", "a"],
                     "col2": [10, 20, 30]})
cinco
# Out:
#   col1  col2
# 0    b    10
# 1    c    20
# 2    a    30

# %%
tres.merge(cinco, 
         how='inner',
         on = "col1")
# Out:
#   col1 col2_x col3 col4  col2_y
# 0    a      d    g    j      30
# 1    b      e    h    k      10
# 2    c      f    i    l      20

# %%
uno.merge(dos, 
         how='outer',
         on = "col1")
# Out:
#    col1  col2_x  col3_x  col2_y  col3_y
# 0     1     4.0     7.0     NaN     NaN
# 1     2     5.0     8.0     NaN     NaN
# 2     3     6.0     9.0     NaN     NaN
# 3    10     NaN     NaN    14.0    18.0
# 4    11     NaN     NaN    15.0    19.0
# 5    12     NaN     NaN    16.0    20.0
# 6    13     NaN     NaN    17.0    21.0

# %%
uno.merge(dos, 
         how='outer',
         on = "col1",
         suffixes=('_dfizq', '_dfder'))
# Out:
#    col1  col2_dfizq  col3_dfizq  col2_dfder  col3_dfder
# 0     1         4.0         7.0         NaN         NaN
# 1     2         5.0         8.0         NaN         NaN
# 2     3         6.0         9.0         NaN         NaN
# 3    10         NaN         NaN        14.0        18.0
# 4    11         NaN         NaN        15.0        19.0
# 5    12         NaN         NaN        16.0        20.0
# 6    13         NaN         NaN        17.0        21.0

# %%
dos.merge(uno, 
         on = "col1",
         how='left')
# Out:
#    col1  col2_x  col3_x  col2_y  col3_y
# 0    10      14      18     NaN     NaN
# 1    11      15      19     NaN     NaN
# 2    12      16      20     NaN     NaN
# 3    13      17      21     NaN     NaN

# %%
dos.merge(uno, 
         on = "col1",
         how='right')
# Out:
#    col1  col2_x  col3_x  col2_y  col3_y
# 0     1     NaN     NaN       4       7
# 1     2     NaN     NaN       5       8
# 2     3     NaN     NaN       6       9

# %%
seis = pd.DataFrame({"c_1": [1,2],
                    "c_2": ["a", "b"]})
seis
# Out:
#    c_1 c_2
# 0    1   a
# 1    2   b

# %%
uno.merge(seis, 
         how="inner",
         left_on = "col1",
         right_on = "c_1")
# Out:
#    col1  col2  col3  c_1 c_2
# 0     1     4     7    1   a
# 1     2     5     8    2   b

# %%
uno.merge(seis, 
         how="left",
         left_on = "col1",
         right_on = "c_1")
# Out:
#    col1  col2  col3  c_1  c_2
# 0     1     4     7  1.0    a
# 1     2     5     8  2.0    b
# 2     3     6     9  NaN  NaN

# %%
uno.merge(seis, 
         how="right",
         left_on = "col1",
         right_on = "c_1")
# Out:
#    col1  col2  col3  c_1 c_2
# 0     1     4     7    1   a
# 1     2     5     8    2   b

# %%
uno.merge(seis, 
         how="outer",
         left_on = "col1",
         right_on = "c_1")
# Out:
#    col1  col2  col3  c_1  c_2
# 0     1     4     7  1.0    a
# 1     2     5     8  2.0    b
# 2     3     6     9  NaN  NaN

# %%
eventos1 = pd.DataFrame({"Evento": ["Id1", "Id2", "Id3"],
                        "Encargado": ["Roberto C.", "Jorge L.", "Lucía M."]},
                        index = ['2018-01-01 00:00:00', 
                                 '2018-01-01 01:00:00',
                                 '2018-01-01 02:00:00'])

# %%
eventos2 = pd.DataFrame({"Ubicación": ["ss_2", "ss_11", "ss_2", "ss_6", "ss_4"],
                        "Repetido": [True, False, False, True, True]},
                        index = ['2018-01-01 00:00:00', 
                                 '2018-01-01 01:00:00',
                                 '2018-01-01 02:00:00',
                                 '2018-01-01 03:00:00',
                                 '2018-01-01 04:00:00'])

# %%
eventos1
# Out:
#                     Evento   Encargado
# 2018-01-01 00:00:00    Id1  Roberto C.
# 2018-01-01 01:00:00    Id2    Jorge L.
# 2018-01-01 02:00:00    Id3    Lucía M.

# %%
eventos2
# Out:
#                     Ubicación  Repetido
# 2018-01-01 00:00:00      ss_2      True
# 2018-01-01 01:00:00     ss_11     False
# 2018-01-01 02:00:00      ss_2     False
# 2018-01-01 03:00:00      ss_6      True
# 2018-01-01 04:00:00      ss_4      True

# %%
eventos1.join(eventos2,
            how = "left")
# Out:
#                     Evento   Encargado Ubicación  Repetido
# 2018-01-01 00:00:00    Id1  Roberto C.      ss_2      True
# 2018-01-01 01:00:00    Id2    Jorge L.     ss_11     False
# 2018-01-01 02:00:00    Id3    Lucía M.      ss_2     False

# %%
eventos1.join(eventos2,
            how = "right")
# Out:
#                     Evento   Encargado Ubicación  Repetido
# 2018-01-01 00:00:00    Id1  Roberto C.      ss_2      True
# 2018-01-01 01:00:00    Id2    Jorge L.     ss_11     False
# 2018-01-01 02:00:00    Id3    Lucía M.      ss_2     False
# 2018-01-01 03:00:00    NaN         NaN      ss_6      True
# 2018-01-01 04:00:00    NaN         NaN      ss_4      True

# %%
eventos1.join(eventos2,
            how = "inner")
# Out:
#                     Evento   Encargado Ubicación  Repetido
# 2018-01-01 00:00:00    Id1  Roberto C.      ss_2      True
# 2018-01-01 01:00:00    Id2    Jorge L.     ss_11     False
# 2018-01-01 02:00:00    Id3    Lucía M.      ss_2     False

# %%
eventos1.join(eventos2,
            how = "outer")
# Out:
#                     Evento   Encargado Ubicación  Repetido
# 2018-01-01 00:00:00    Id1  Roberto C.      ss_2      True
# 2018-01-01 01:00:00    Id2    Jorge L.     ss_11     False
# 2018-01-01 02:00:00    Id3    Lucía M.      ss_2     False
# 2018-01-01 03:00:00    NaN         NaN      ss_6      True
# 2018-01-01 04:00:00    NaN         NaN      ss_4      True
